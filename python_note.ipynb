# %% [markdown]
# <a href="https://colab.research.google.com/github/ggggddfghukkb-glitch/Python-Corob/blob/main/python_note.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Pythonの勉強を続けていきたいと思います")
print("諦めません")
# Out:
# Pythonの勉強を続けていきたいと思います
# 諦めません

# %%
print(100)
print(3.14)
# Out:
# 100
# 3.14

# %%
print(100)
print("100")
# Out:
# 100
# 100

# %%
print("こんにちは")
# Out:
# こんにちは

# %%
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7276/2122694447.py in <cell line: 0>()
# ----> 1 print(name)
#
# NameError: name 'name' is not defined

# %%
print("indennto")
    print("indento")
# Out:
#   File "/tmp/ipykernel_1366/2913218511.py", line 2
#     print("indento")
#     ^
# IndentationError: unexpected indent

# %%
print("一行目")
    print("二行目")
print("三行目")
# Out:
#   File "/tmp/ipykernel_1366/1332379055.py", line 2
#     print("二行目")
#     ^
# IndentationError: unexpected indent

# %%
name="だいじん"
greeting=name+"です。よろしくおねがいします。"
print(greeting)
print(len(greeting))
# Out:
# だいじんです。よろしくおねがいします。
# 19

# %%
daizin="rokkouzan"
print(daizin.upper())
print(daizin.lower())
# Out:
# ROKKOUZAN
# rokkouzan

# %%
print(5*5*3.14)
print(17//5)
print(17%5)
# Out:
# 78.5
# 3
# 2

# %%
print(2+3*2)
print((2+3)*2)
# Out:
# 8
# 10

# %%
print(1>3)
print(3<1)
print(3>=1)
print(1<=3)
print(1==1)
print(1!=3)
# Out:
# False
# False
# True
# True
# True
# True

# %%
print("魚"=="魚")
print("魚"=="カブトガニ")
# Out:
# True
# False

# %%
result=None
print(result)
print(None==0)
# Out:
# None
# False

# %%
print(result is None)
# Out:
# True

# %%
print(int("100")+50)
nennrei=str(42)
print("私の年齢は"+nennrei+"歳です")
# Out:
# 150
# 私の年齢は42歳です

# %%
nennrei2=float("9.8")
print(nennrei2*2)
# Out:
# 19.6

# %%
price=1000
price-=200
print(price)
# Out:
# 800

# %%
x,y=10,20
sora=x+y
print(sora)
# Out:
# 30

# %%
temperature=30
if temperature>=25:
  print("暑いです")

temperature-=20
if temperature>=25:
  print("暑いです")
# Out:
# 暑いです

# %%
score=60
if score==60:
  print("当たりました")
  print("おめでとうございます！")
# Out:
# 当たりました
# おめでとうございます！

# %%
score=120
if score>=100:
  print("クリア")
else:
  print("もう少し")
# Out:
# クリア

# %%
age=17
if age>=18:
  print("大人です")
else:
  print("子供です")
# Out:
# 子供です

# %%
weather="晴れ"
if weather=="晴れ" or weather=="くもり":
  print("出かけましょう")
# Out:
# 出かけましょう

# %%
age=38
has_ticket=True
if age>=18 and has_ticket:
  print("入場できます")
# Out:
# 入場できます

# %%
is_raining=True
if not is_raining:
  print("傘は不要です")
else:
  print("傘は必要です")
# Out:
# 傘は必要です

# %%
for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,11,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(1,21):
  if i%3==0:
    print(i)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18

# %%
for i in range(10):
  if i%2!=0:
    continue
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
total=0
for i in range(100):
  total=total+i
  if total>20:
    break
print(total)
# Out:
# 21

# %%
foods=["寿司","ピザ","ヨーグルト"]
for food in foods:
  if food=="寿司":
    break
print("寿司")
# Out:
# 寿司

# %%
def introduce():
  print("俺の名前は大輔。")
  print("趣味はゲーム")
  print("ニート")

introduce()

introduce()
# Out:
# 俺の名前は大輔。
# 趣味はゲーム
# ニート
# 俺の名前は大輔。
# 趣味はゲーム
# ニート

# %%
def check_number(n):
  if n<0:
    print("0より小さい")
  elif n==0:
    print(0)
  else:
    print("0より大きい")

check_number(0)

check_number(-1)

check_number(2)
# Out:
# 0
# 0より小さい
# 0より大きい

# %%
def multiply(a,b):
  return a*b

print(multiply(3,8))

print(multiply(2,3)+multiply(4,5))
# Out:
# 24
# 26

# %%
def seyHello(name="名無し"):
  print(name+"さん、こんにちは")

seyHello("kameo")
# Out:
# kameoさん、こんにちは

# %%
foods=["寿司","ピザ","ヨーグルト"]
print(foods[1])
foods.append("ラーメン")

print(foods)
print(len(foods))

foods.remove("寿司")
print(foods[-1])
# Out:
# ピザ
# ['寿司', 'ピザ', 'ヨーグルト', 'ラーメン']
# 4
# ラーメン

# %%
collars={"Red":"赤","Yellow":"黄色","blue":"青"}

print(collars["Red"])

collars["purple"]="紫"

print(collars)

print("name"in collars)

print("hobby"in collars)
# Out:
# 赤
# {'Red': '赤', 'Yellow': '黄色', 'blue': '青', 'purple': '紫'}
# False
# False

# %%
suuzi=[1,2,3,4,5]
for n in suuzi:
  print(n*2)

suuzi2=[10,15,20,25,30]
for n in suuzi2:
  if n>=20:
    print(n)

hutari=[{"name":"大輔","age":42},
        {"name":"滝子","age":68}]

for n in hutari:
  printn["name"]+"さんは"+str(n["age"])+"歳です"）
# Out:
# 2
# 4
# 6
# 8
# 10
# 20
# 25
# 30
# 大輔さんは42歳です
# 滝子さんは68歳です

# %%
import random

suuzi2=random.randint(1,10)

print(suuzi2)


kotobas=["頑張る","愛","勉強"]

kotoba=random.choice(kotobas)

print(kotoba)


import datetime

time=datetime.datetime.now()

print(time)
# Out:
# 5
# 愛
# 2026-09-03 05:33:29.970833

# %%
name="大輔"

message="私は神だ"

page="<h1>"+name+"のページだよ"+"</h1><p>"+message+"</p>"

print(page)


suki="<ul><li>寿司</li><li>ピザ</li><li>ヨーグルト</li></ul>"

print(suki)
# Out:
# <h1>大輔のページだよ</h1><p>私は神だ</p>
# <ul><li>寿司</li><li>ピザ</li><li>ヨーグルト</li></ul>
